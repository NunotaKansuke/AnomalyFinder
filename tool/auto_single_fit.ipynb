# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy.optimize as op
import warnings
import time
import emcee
from matplotlib import rcParams
import AnomalyFinder as af

# %%
file_name = "../suzuki16/data/MOAR_MB07308.dat"

data = np.genfromtxt(file_name,usecols=[0,1,2],names=["time","flux","ferr"])
data["time"]-=2450000
del_ind = np.where((data["time"] < 1000) | (data["ferr"] <= 0)) 
data= np.delete(data, del_ind)

# %%
plt.scatter(data["time"],data["flux"])
plt.show()

# %%
a
