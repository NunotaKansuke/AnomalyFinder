# %%
import sys
sys.path.append("../source/")
import numpy as np
import matplotlib.pyplot as plt
import AnomalyFinder as af

# %%
finder = af.AnomalyFinder()

finder.set_data("../moaphot/phot-gb7-R-3/mb08294-R-90001.phot.dat",subtract_2450000=True)

finder.PSPL_fit()
# Out:
# Total time for the search: 7.385412931442261 seconds

# %%
print(finder.t0_PSPL)
print(finder.tE_PSPL)
print(finder.u0_PSPL)
# Out:
# 9516.79846237271
# 4.769727421954865
# 5.339704442365704

# %%
finder.plot_residual_from_PSPL()

finder.normalize_error(toeff=10)
# Out:
# coefficient for erroe normalization is 3.837447229051002

# %%
finder.run_grid_search(teff_init=0.3,teff_grid=10,common_ratio=4/3)
# Out:
# Total time for the search: 35.33470106124878 seconds

# %%
finder.show_grid_search_result(s=1)
plt.show()

# %%
finder.show_anomaly_signal(which="zero",markersize=3,capsize=2)

finder.show_anomaly_signal(which="flat",markersize=3,capsize=2)

plt.show()
# Out:
# f1=  -10944.802814538445  f0=  21970.372714994985
# f1=  1544011.6931755897  f0=  -2323474.401232367
